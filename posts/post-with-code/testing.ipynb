# %%
# !pip install llmtools
# Out:
# ...
#   Obtaining dependency information for llmtools from https://files.pythonhosted.org/packages/2d/27/ff62c75c84038b1c9a6b08ad060ca324638ffd7f526ca170ffa8488f28c9/llmtools-0.0.2-py3-none-any.whl.metadata
#   Using cached llmtools-0.0.2-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/21/02/ae8e595f45b6c8edee07913892b3b41f5f5f273962ad98851dc6a564bbb9/transformers-4.31.0-py3-none-any.whl.metadata
#   Using cached transformers-4.31.0-py3-none-any.whl.metadata (116 kB)
# ...
#   Using cached torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl (619.9 MB)
# ...
#   Obtaining dependency information for accelerate from https://files.pythonhosted.org/packages/70/f9/c381bcdd0c3829d723aa14eec8e75c6c377b4ca61ec68b8093d9f35fc7a7/accelerate-0.21.0-py3-none-any.whl.metadata
#   Using cached accelerate-0.21.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from llmtools.Train import *
#
# ModuleNotFoundError: No module named 'llmtools.Train'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 recursive_folder_search
#
# NameError: name 'recursive_folder_search' is not defined
